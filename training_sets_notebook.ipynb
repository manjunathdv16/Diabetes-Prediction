# %%
import mlflow

experiment_id = mlflow.create_experiment(
  "my-experiment-name",
  tags={"version": "v1", "priority": "P1"},
)

with mlflow.start_run(experiment_id=experiment_id):
  mlflow.log_param("hello", "mlflow")
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mlflow
# ----> 3 experiment_id = mlflow.create_experiment(
#       4   "my-experiment-name",
#       5   tags={"version": "v1", "priority": "P1"},
#       6 )
#       8 with mlflow.start_run(experiment_id=experiment_id):
#       9   mlflow.log_param("hello", "mlflow")
#
# File /opt/conda/lib/python3.10/site-packages/mlflow/tracking/fluent.py:2089, in create_experiment(name, artifact_location, tags)
#    2041 def create_experiment(
#    2042     name: str,
#    2043     artifact_location: Optional[str] = None,
#    2044     tags: Optional[dict[str, Any]] = None,
#    2045 ) -> str:
#    2046     """
#    2047     Create an experiment.
#    2048
#    (...)
#    2087         Creation timestamp: 1662004217511
#    2088     """
# ...

# %%
from domino_data.training_sets.client import create_training_set_version

print(create_training_set_version)
# Out:
# <function create_training_set_version at 0x775272eae170>

# %%
import domino_data.training_sets as ts

print(dir(ts))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'client', 'model']

# %%
import domino_data.training_sets.client as client

print(dir(client))
# Out:
# ['AuthenticatedClient', 'CreateTrainingSetVersionRequest', 'CreateTrainingSetVersionRequestMeta', 'List', 'Mapping', 'MonitoringMeta', 'Optional', 'Response', 'S_IRGRP', 'S_IROTH', 'S_IRUSR', 'S_IWUSR', 'S_IXGRP', 'S_IXOTH', 'S_IXUSR', 'SchemaMismatchException', 'ServerException', 'TrainingSet', 'TrainingSetFilter', 'TrainingSetFilterMeta', 'TrainingSetVersion', 'TrainingSetVersionFilter', 'TrainingSetVersionFilterMeta', 'TrainingSetVersionFilterTrainingSetMeta', 'UpdateTrainingSetRequest', 'UpdateTrainingSetRequestMeta', 'UpdateTrainingSetVersionRequest', 'UpdateTrainingSetVersionRequestMeta', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_columns', '_get_client', '_get_project_id', '_raise_response_exn', '_to_TrainingSet', '_to_TrainingSetVersion', '_trainingset_name_pat', '_validate_trainingset_name', 'create_training_set_version', 'delete_training_set', 'delete_training_set_name', 'delete_training_set_name_number'
# ...

# %%
from domino_data.training_sets.client import list_training_sets

training_sets = list_training_sets()

print(f"Found {len(training_sets)} training sets:\n")

for ts in training_sets:
    print(ts)
# Out:
# Found 1 training sets:
#
# TrainingSet(name='diabetes-training-set', project_id='6a679ebddf92ab733f310dae', description=<training_set_api_client.types.Unset object at 0x775272fc26e0>, meta={})

# %%
from domino_data.training_sets.client import get_training_set

ts = get_training_set("diabetes-training-set")

print(ts)
# Out:
# TrainingSet(name='diabetes-training-set', project_id='6a679ebddf92ab733f310dae', description=<training_set_api_client.types.Unset object at 0x775272fc26e0>, meta={})

# %%
from domino_data.training_sets.client import list_training_set_versions

versions = list_training_set_versions(
    training_set_name="diabetes-training-set"
)

print(versions)
# Out:
# [TrainingSetVersion(training_set_name='diabetes-training-set', number=1, description='Training data for Diabetes Prediction Model', key_columns=[], target_columns=['Outcome'], exclude_columns=[], all_columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'], monitoring_meta=MonitoringMeta(timestamp_columns=[], categorical_columns=[], ordinal_columns=[]), meta={}, path='/trainingset/6a679ebddf92ab733f310dae/6a67ab0cdf92ab733f310e0c/6a67ab0cdf92ab733f310e0d', container_path='6a67ab0cdf92ab733f310e0c/6a67ab0cdf92ab733f310e0d', pending=False), TrainingSetVersion(training_set_name='diabetes-training-set', number=2, description='Training data for Diabetes Prediction Model', key_columns=[], target_columns=['Outcome'], exclude_columns=[], all_columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'], monitoring_meta=MonitoringMeta(timestamp_col
# ...

# %%
versions = list_training_set_versions(
    training_set_name='diabetes-training-set'
)
print(versions)
# Out:
# [TrainingSetVersion(training_set_name='diabetes-training-set', number=1, description='Training data for Diabetes Prediction Model', key_columns=[], target_columns=['Outcome'], exclude_columns=[], all_columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'], monitoring_meta=MonitoringMeta(timestamp_columns=[], categorical_columns=[], ordinal_columns=[]), meta={}, path='/trainingset/6a679ebddf92ab733f310dae/6a67ab0cdf92ab733f310e0c/6a67ab0cdf92ab733f310e0d', container_path='6a67ab0cdf92ab733f310e0c/6a67ab0cdf92ab733f310e0d', pending=False), TrainingSetVersion(training_set_name='diabetes-training-set', number=2, description='Training data for Diabetes Prediction Model', key_columns=[], target_columns=['Outcome'], exclude_columns=[], all_columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'], monitoring_meta=MonitoringMeta(timestamp_col
# ...

# %%
from domino_data.training_sets.client import create_training_set_version
import inspect

print(inspect.signature(create_training_set_version))
# Out:
# (training_set_name: str, df: pandas.core.frame.DataFrame, description: Optional[str] = None, key_columns: Optional[List[str]] = None, target_columns: Optional[List[str]] = None, exclude_columns: Optional[List[str]] = None, monitoring_meta: Optional[domino_data.training_sets.model.MonitoringMeta] = None, meta: Optional[Mapping[str, str]] = None, **kwargs) -> domino_data.training_sets.model.TrainingSetVersion

# %%
from domino_data.training_sets.model import MonitoringMeta
import inspect

print(inspect.signature(MonitoringMeta))
# Out:
# (timestamp_columns: List[str] = <factory>, categorical_columns: List[str] = <factory>, ordinal_columns: List[str] = <factory>) -> None

# %%
from domino_data.training_sets.model import TrainingSetVersion

print(dir(TrainingSetVersion))
from domino_data.training_sets.model import *

print(dir())
version = create_training_set_version(...)

print(version.__dict__)
# Out:
# ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'absolute_container_path', 'container_path', 'description', 'load_raw_pandas', 'load_training_pandas', 'path', 'pending']
# ...

# %%
from domino_data.training_sets.client import get_training_set_version

ts = get_training_set_version(
    "diabetes-training-set-v3",
    1
)

df = ts.load_training_pandas()

print(df.head())
print(df.shape)
print(df.dtypes)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# (768, 9)
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# ...

# %%
raw_df = ts.load_raw_pandas()

print(raw_df.head())
print(raw_df.shape)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# (768, 9)

# %%
import domino_data

print(domino_data.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 import domino_data
# ----> 3 print(domino_data.__version__)
#
# AttributeError: module 'domino_data' has no attribute '__version__'

# %%
import pkg_resources

print(pkg_resources.get_distribution("domino-data"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import pkg_resources
#       3 print(pkg_resources.get_distribution("domino-data"))
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
import importlib.metadata

print(importlib.metadata.version("domino-data"))
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[24], line 3
#       1 import importlib.metadata
# ----> 3 print(importlib.metadata.version("domino-data"))
#
# File /opt/conda/lib/python3.10/importlib/metadata/__init__.py:996, in version(distribution_name)
#     989 def version(distribution_name):
#     990     """Get the version string for the named package.
#     991
#     992     :param distribution_name: The name of the distribution package to query.
#     993     :return: The version string for the package as defined in the package's
#     994         "Version" metadata key.
#     995     """
# --> 996     return distribution(distribution_name).version
#
# File /opt/conda/lib/python3.10/importlib/metadata/__init__.py:969, in distribution(distribution_name)
#     963 def distribution(distribution_name):
# ...
